# %% [markdown]
# # Varying the B field
#
# Now we will analyse how the simulation results, looking at diffusion constant D and possible exponent, will change with the B field, keeping other variables fixed.
#
# The previously used functions can now be found in the separate python module 'Diffulyzer'.

# %%
# %matplotlib inline

from Diffulyzer import *

num_candidates = 300
EMin = 1 * EeV
EMax = 1 * EeV
num_samples = 200
max_trajectory_length = 100 * Mpc
grid_size = 256
grid_spacing = 30 * kpc
lMin = 100 * kpc
lMax = 1000 * kpc
alpha = -11./3.

Brms_min = 10 * nG
Brms_max = 100 * nG
variation_steps = 9
variation_repeat = 3

# %% [markdown]
# With the above settings we run a bunch of simulations. Now we will skip the trajectories, as they don't tell us anything new. We will keep the <r²> plots to be able to check soundness.

# %%
delta_B = (Brms_max - Brms_min) / variation_steps
Bs = []
Ds = []
exponents = []
for i in range(variation_steps):
    Brms = Brms_min + i * delta_B
    for j in range(variation_repeat):
        nr = 'Fit ' + str(i*variation_repeat+j+1) + '/' + str(variation_steps*variation_repeat)
        plot_title = nr + ', Brms=' + str(Brms / nG) + ' nG, E=' + str(EMin / EeV) + ' EeV'
        Bs.append(Brms / nG)
        data = sim(num_candidates, num_samples, max_trajectory_length, EMin, EMax, grid_size, grid_spacing, Brms, lMin, lMax, alpha)
        D, exponent = plot_rms(data, plot_title)
        Ds.append(D)
        exponents.append(exponent)
# Out:
# After last step:
# r_min   = 1.07679233555
# r_max   = 15.2856318344
# < r >   = 6.55278075856
# < r >²  = 42.9389356698
# < r² >  = 51.1854798603
# sigma_r = 2.87167968105
#
# Over all data points:
# D       = 0.433085140408
# exponent= 1.04015836716
#
# r²     ~= 0.433085140408 d ^ 1.04015836716
# After last step:
# r_min   = 0.4426481398
# r_max   = 14.2428521727
# < r >   = 6.92007358005
# < r >²  = 47.8874183532
# < r² >  = 56.4336834957
# sigma_r = 2.92339958653
#
# Over all data points:
# D       = 0.463783253298
# exponent= 1.04541542147
#
# r²     ~= 0.463783253298 d ^ 1.04541542147
# After last step:
# r_min   = 1.25901007368
# r_max   = 16.6101059708
# < r >   = 6.7872749471
# < r >²  = 46.0671012075
# < r² >  = 53.9362906304
# sigma_r = 2.80520755432
#
# Over all data points:
# D       = 0.452915227649
# exponent= 1.04143385796
#
# r²     ~= 0.452915227649 d ^ 1.04143385796
# After last step:
# r_min   = 0.376468685821
# r_max   = 12.2001719261
# < r >   = 4.8232135515
# < r >²  = 23.2633889633
# < r² >  = 27.3997600866
# sigma_r = 2.03380705162
#
# Over all data points:
# D       = 0.248515994791
# exponent= 1.02173081335
#
# r²     ~= 0.248515994791 d ^ 1.02173081335
# After last step:
# r_min   = 0.214607139232
# r_max   = 10.1141883354
# < r >   = 4.72428617115
# < r >²  = 22.3188798269
# < r² >  = 26.3183273116
# sigma_r = 1.99986186641
#
# Over all data points:
# D       = 0.236033665925
# exponent= 1.02400589925
#
# r²     ~= 0.236033665925 d ^ 1.02400589925
# After last step:
# r_min   = 0.68469465415
# r_max   = 11.6883728218
# < r >   = 4.63271235808
# < r >²  = 21.4620237927
# < r² >  = 25.1735701418
# sigma_r = 1.92653739884
#
# Over all data points:
# D       = 0.242955909418
# exponent= 1.00299688353
#
# r²     ~= 0.242955909418 d ^ 1.00299688353
# After last step:
# r_min   = 0.325873805642
# r_max   = 9.23929585903
# < r >   = 3.97478583739
# < r >²  = 15.7989224531
# < r² >  = 18.6256417713
# sigma_r = 1.68128501991
#
# Over all data points:
# D       = 0.255100409055
# exponent= 0.931312134858
#
# r²     ~= 0.255100409055 d ^ 0.931312134858
# After last step:
# r_min   = 0.273256694965
# r_max   = 11.3445193591
# < r >   = 3.84162568273
# < r >²  = 14.7580878862
# < r² >  = 17.5970002454
# sigma_r = 1.68490722569
#
# Over all data points:
# D       = 0.154491986737
# exponent= 1.02491511984
#
# r²     ~= 0.154491986737 d ^ 1.02491511984
# After last step:
# r_min   = 0.328133672555
# r_max   = 9.62658412523
# < r >   = 3.96769501981
# < r >²  = 15.7426037702
# < r² >  = 18.3844880238
# sigma_r = 1.62538741647
#
# Over all data points:
# D       = 0.174318669086
# exponent= 1.01471437643
#
# r²     ~= 0.174318669086 d ^ 1.01471437643
# After last step:
# r_min   = 0.223479079821
# r_max   = 8.47937353516
# < r >   = 3.61688089915
# < r >²  = 13.0818274386
# < r² >  = 15.3348381087
# sigma_r = 1.5010032212
#
# Over all data points:
# D       = 0.12975107592
# exponent= 1.03123498981
#
# r²     ~= 0.12975107592 d ^ 1.03123498981
# After last step:
# r_min   = 0.505647288451
# r_max   = 9.18149399494
# < r >   = 3.51922201218
# < r >²  = 12.384923571
# < r² >  = 14.9526981961
# sigma_r = 1.6024277285
#
# Over all data points:
# D       = 0.150001103938
# exponent= 0.995028534328
#
# r²     ~= 0.150001103938 d ^ 0.995028534328
# After last step:
# r_min   = 0.550201089989
# r_max   = 8.35849756456
# < r >   = 3.49269055273
# < r >²  = 12.1988872971
# < r² >  = 14.6844204564
# sigma_r = 1.57655737582
#
# Over all data points:
# D       = 0.198446789255
# exponent= 0.935702145999
#
# r²     ~= 0.198446789255 d ^ 0.935702145999
# After last step:
# r_min   = 0.120704450311
# r_max   = 7.40014927184
# < r >   = 3.23449959028
# < r >²  = 10.4619875995
# < r² >  = 12.7020911162
# sigma_r = 1.49669753681
#
# Over all data points:
# D       = 0.121222830809
# exponent= 1.00782737755
#
# r²     ~= 0.121222830809 d ^ 1.00782737755
# After last step:
# r_min   = 0.810113419555
# r_max   = 8.84475117271
# < r >   = 3.43676576571
# < r >²  = 11.8113589284
# < r² >  = 13.9684120891
# sigma_r = 1.46869096843
#
# Over all data points:
# D       = 0.142079194979
# exponent= 0.989956021952
#
# r²     ~= 0.142079194979 d ^ 0.989956021952
# After last step:
# r_min   = 0.213668102859
# r_max   = 8.45357154574
# < r >   = 3.34263571374
# < r >²  = 11.1732135147
# < r² >  = 13.0825704351
# sigma_r = 1.38179481849
#
# Over all data points:
# D       = 0.172090519097
# exponent= 0.943683423545
#
# r²     ~= 0.172090519097 d ^ 0.943683423545
# After last step:
# r_min   = 0.461951302816
# r_max   = 7.66347470463
# < r >   = 3.24823727554
# < r >²  = 10.5510453982
# < r² >  = 12.4186266247
# sigma_r = 1.36659475576
#
# Over all data points:
# D       = 0.148734021034
# exponent= 0.95146119914
#
# r²     ~= 0.148734021034 d ^ 0.95146119914
# After last step:
# r_min   = 0.190127481781
# r_max   = 7.75704864971
# < r >   = 3.29766931167
# < r >²  = 10.8746228892
# < r² >  = 12.7960735374
# sigma_r = 1.38616400483
#
# Over all data points:
# D       = 0.1457718908
# exponent= 0.974081143587
#
# r²     ~= 0.1457718908 d ^ 0.974081143587
# After last step:
# r_min   = 0.329185085892
# r_max   = 8.39324707206
# < r >   = 3.27521234457
# < r >²  = 10.727015902
# < r² >  = 12.5781321852
# sigma_r = 1.36055734284
#
# Over all data points:
# D       = 0.15741616167
# exponent= 0.947441415522
#
# r²     ~= 0.15741616167 d ^ 0.947441415522
# After last step:
# r_min   = 0.476163273879
# r_max   = 7.84709920769
# < r >   = 3.02857377332
# < r >²  = 9.17225910042
# < r² >  = 10.9494091146
# sigma_r = 1.33309790119
#
# Over all data points:
# D       = 0.116364224063
# exponent= 0.983737951985
#
# r²     ~= 0.116364224063 d ^ 0.983737951985
# After last step:
# r_min   = 0.252500977888
# r_max   = 7.12321077851
# < r >   = 3.05749814001
# < r >²  = 9.34829487617
# < r² >  = 10.9962004038
# sigma_r = 1.28370772672
#
# Over all data points:
# D       = 0.205964927747
# exponent= 0.868006315441
#
# r²     ~= 0.205964927747 d ^ 0.868006315441
# After last step:
# r_min   = 0.288259068631
# r_max   = 7.71317262663
# < r >   = 3.11527967919
# < r >²  = 9.70496747958
# < r² >  = 11.6414557347
# sigma_r = 1.39157761376
#
# Over all data points:
# D       = 0.0985133596087
# exponent= 1.03988801614
#
# r²     ~= 0.0985133596087 d ^ 1.03988801614
# After last step:
# r_min   = 0.527057227955
# r_max   = 8.37523676613
# < r >   = 3.0331153763
# < r >²  = 9.19978888596
# < r² >  = 11.1520639322
# sigma_r = 1.39723836413
#
# Over all data points:
# D       = 0.070380897192
# exponent= 1.10485573602
#
# r²     ~= 0.070380897192 d ^ 1.10485573602
# After last step:
# r_min   = 0.345555971249
# r_max   = 7.80641109555
# < r >   = 3.02611538427
# < r >²  = 9.15737431893
# < r² >  = 10.9264622067
# sigma_r = 1.33007063263
#
# Over all data points:
# D       = 0.10425958471
# exponent= 1.0097338013
#
# r²     ~= 0.10425958471 d ^ 1.0097338013
# After last step:
# r_min   = 0.265631006587
# r_max   = 6.89674067463
# < r >   = 3.01467888853
# < r >²  = 9.08828880093
# < r² >  = 11.0679805556
# sigma_r = 1.40701519346
#
# Over all data points:
# D       = 0.144586742964
# exponent= 0.939492114465
#
# r²     ~= 0.144586742964 d ^ 0.939492114465
# After last step:
# r_min   = 0.572687693432
# r_max   = 7.41697433205
# < r >   = 3.09603250584
# < r >²  = 9.58541727724
# < r² >  = 11.257474513
# sigma_r = 1.29308052177
#
# Over all data points:
# D       = 0.100456484688
# exponent= 1.0287679594
#
# r²     ~= 0.100456484688 d ^ 1.0287679594
# After last step:
# r_min   = 0.340754627178
# r_max   = 7.92659790427
# < r >   = 3.02097999766
# < r >²  = 9.12632014625
# < r² >  = 10.8064745783
# sigma_r = 1.29620771178
#
# Over all data points:
# D       = 0.0750518211551
# exponent= 1.08380575516
#
# r²     ~= 0.0750518211551 d ^ 1.08380575516
# After last step:
# r_min   = 0.312340088644
# r_max   = 7.22047625997
# < r >   = 2.91587739899
# < r >²  = 8.50234100591
# < r² >  = 10.1798448141
# sigma_r = 1.29518485485
#
# Over all data points:
# D       = 0.0928926458893
# exponent= 1.02636199045
#
# r²     ~= 0.0928926458893 d ^ 1.02636199045

# %% [markdown]
# An overview of all results shows the dependency on the B field strength.

# %%
figure(figsize=(9, 5))
title('D ~ Brms, E=' + str(EMin / EeV) + ' EeV')
scatter(Bs, Ds, s=50)
grid()
ylabel('D')
xlabel('Brms [nG]')
legend()
show()

figure(figsize=(9, 5))
title('exponent ~ Brms, E=' + str(EMin / EeV) + ' EeV')
scatter(Bs, exponents, s=50)
grid()
ylabel('exponent')
xlabel('Brms [nG]')
legend()
show()

# %% [markdown]
# This looks like a rough dependency of D ~ 1 / B. The exponent stays close to 1 which is the diffusion realm. If it was going up to 2 we were back in the ballistic motion, but here diffusion is a good description of the motion.
