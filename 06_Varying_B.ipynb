# %% [markdown]
# # Varying the B field
#
# Now we will analyse how the simulation results, looking at diffusion constant D and possible exponent, will change with the B field, keeping other variables fixed.
#
# The previously used functions can now be found in the separate python module 'Diffulyzer'.

# %%
# %matplotlib inline

from Diffulyzer import *

num_candidates = 300
EMin = 1 * EeV
EMax = 1 * EeV
num_samples = 200
max_trajectory_length = 100 * Mpc
grid_size = 256
grid_spacing = 30 * kpc
lMin = 100 * kpc
lMax = 1000 * kpc
alpha = -11./3.

Brms_min = 10 * nG
Brms_max = 100 * nG
variation_steps = 10
variation_repeat = 3

# %% [markdown]
# With the above settings we run a bunch of simulations. Now we will skip the trajectories, as they don't tell us anything new. We will keep the <r²> plots to be able to check soundness.

# %%
delta_B = (Brms_max - Brms_min) / (variation_steps-1)
Bs = []
Ds = []
exponents = []
for i in range(variation_steps):
    Brms = Brms_min + i * delta_B
    for j in range(variation_repeat):
        nr = 'Fit ' + str(i*variation_repeat+j+1) + '/' + str(variation_steps*variation_repeat)
        plot_title = nr + ', Brms=' + str(Brms / nG) + ' nG, E=' + str(EMin / EeV) + ' EeV'
        Bs.append(Brms / nG)
        data = sim(num_candidates, num_samples, max_trajectory_length, EMin, EMax, grid_size, grid_spacing, Brms, lMin, lMax, alpha)
        D, exponent = plot_rms(data, plot_title)
        Ds.append(D)
        exponents.append(exponent)
# Out:
# After last step:
# r_min   = 0.829656753264
# r_max   = 17.8340691984
# < r >   = 6.79390954605
# < r >²  = 46.15720692
# < r² >  = 55.2347861366
# sigma_r = 3.0129021253
#
# Over all data points:
# D       = 0.689570307237
# exponent= 0.958195915514
#
# r²     ~= 0.689570307237 d ^ 0.958195915514
# After last step:
# r_min   = 0.797200944612
# r_max   = 15.8325167906
# < r >   = 6.7819536171
# < r >²  = 45.9948948645
# < r² >  = 53.6678883894
# sigma_r = 2.7700168817
#
# Over all data points:
# D       = 0.503990655688
# exponent= 1.01358547874
#
# r²     ~= 0.503990655688 d ^ 1.01358547874
# After last step:
# r_min   = 0.965322873149
# r_max   = 18.3510090471
# < r >   = 6.61946760434
# < r >²  = 43.8173513649
# < r² >  = 53.4740852765
# sigma_r = 3.1075285858
#
# Over all data points:
# D       = 0.59657190297
# exponent= 0.979342828601
#
# r²     ~= 0.59657190297 d ^ 0.979342828601
# After last step:
# r_min   = 0.480260143171
# r_max   = 11.4877517329
# < r >   = 4.71679934992
# < r >²  = 22.2481961074
# < r² >  = 25.9448504013
# sigma_r = 1.92266853458
#
# Over all data points:
# D       = 0.252922562434
# exponent= 1.00695344337
#
# r²     ~= 0.252922562434 d ^ 1.00695344337
# After last step:
# r_min   = 0.459789536599
# r_max   = 10.812453104
# < r >   = 4.65446175707
# < r >²  = 21.6640142481
# < r² >  = 25.8936819
# sigma_r = 2.05661558195
#
# Over all data points:
# D       = 0.21642841396
# exponent= 1.0500810432
#
# r²     ~= 0.21642841396 d ^ 1.0500810432
# After last step:
# r_min   = 0.679883890845
# r_max   = 10.7401014815
# < r >   = 4.7002078416
# < r >²  = 22.0919537542
# < r² >  = 25.8877071024
# sigma_r = 1.94826932125
#
# Over all data points:
# D       = 0.308585279405
# exponent= 0.955724798307
#
# r²     ~= 0.308585279405 d ^ 0.955724798307
# After last step:
# r_min   = 0.658226111518
# r_max   = 8.82417814532
# < r >   = 3.96935300595
# < r >²  = 15.7557632858
# < r² >  = 18.4311754147
# sigma_r = 1.63566870999
#
# Over all data points:
# D       = 0.184201395546
# exponent= 1.00420242217
#
# r²     ~= 0.184201395546 d ^ 1.00420242217
# After last step:
# r_min   = 0.624670527974
# r_max   = 11.5855952577
# < r >   = 3.88093770544
# < r >²  = 15.0616774735
# < r² >  = 17.7068534239
# sigma_r = 1.62639968963
#
# Over all data points:
# D       = 0.218656160542
# exponent= 0.955617005318
#
# r²     ~= 0.218656160542 d ^ 0.955617005318
# After last step:
# r_min   = 0.390607846993
# r_max   = 10.3672092114
# < r >   = 3.98532200785
# < r >²  = 15.8827915063
# < r² >  = 18.825342739
# sigma_r = 1.71538661319
#
# Over all data points:
# D       = 0.150012792522
# exponent= 1.04758148573
#
# r²     ~= 0.150012792522 d ^ 1.04758148573
# After last step:
# r_min   = 0.458475735847
# r_max   = 7.603924645
# < r >   = 3.56541016905
# < r >²  = 12.7121496736
# < r² >  = 15.0234535768
# sigma_r = 1.5202973075
#
# Over all data points:
# D       = 0.106897880588
# exponent= 1.07606943186
#
# r²     ~= 0.106897880588 d ^ 1.07606943186
# After last step:
# r_min   = 0.259638369441
# r_max   = 9.07216381185
# < r >   = 3.57965009843
# < r >²  = 12.8138948272
# < r² >  = 15.1633981001
# sigma_r = 1.53280894861
#
# Over all data points:
# D       = 0.151819667595
# exponent= 0.999496895284
#
# r²     ~= 0.151819667595 d ^ 0.999496895284
# After last step:
# r_min   = 0.300354443329
# r_max   = 8.3664701909
# < r >   = 3.61403583575
# < r >²  = 13.0612550221
# < r² >  = 15.2047597469
# sigma_r = 1.46407128405
#
# Over all data points:
# D       = 0.148282268835
# exponent= 1.00895181821
#
# r²     ~= 0.148282268835 d ^ 1.00895181821
# After last step:
# r_min   = 0.292289128377
# r_max   = 7.90889851134
# < r >   = 3.38864228662
# < r >²  = 11.4828965467
# < r² >  = 13.7482173798
# sigma_r = 1.50509828021
#
# Over all data points:
# D       = 0.166113307999
# exponent= 0.969553106334
#
# r²     ~= 0.166113307999 d ^ 0.969553106334
# After last step:
# r_min   = 0.468292809512
# r_max   = 8.06692376854
# < r >   = 3.42127154189
# < r >²  = 11.7050989633
# < r² >  = 13.5847760755
# sigma_r = 1.37101316994
#
# Over all data points:
# D       = 0.164027584723
# exponent= 0.958804109521
#
# r²     ~= 0.164027584723 d ^ 0.958804109521
# After last step:
# r_min   = 0.227758546729
# r_max   = 8.03024876842
# < r >   = 3.27491965636
# < r >²  = 10.7250987556
# < r² >  = 12.6591371856
# sigma_r = 1.39069710217
#
# Over all data points:
# D       = 0.194074083494
# exponent= 0.905931284485
#
# r²     ~= 0.194074083494 d ^ 0.905931284485
# After last step:
# r_min   = 0.375492941087
# r_max   = 7.43344199535
# < r >   = 3.17366471992
# < r >²  = 10.0721477545
# < r² >  = 12.1774196051
# sigma_r = 1.45095549575
#
# Over all data points:
# D       = 0.133072044624
# exponent= 0.977856578725
#
# r²     ~= 0.133072044624 d ^ 0.977856578725
# After last step:
# r_min   = 0.352616050861
# r_max   = 7.80112490313
# < r >   = 3.31329819398
# < r >²  = 10.9779449222
# < r² >  = 13.0372121818
# sigma_r = 1.43501472453
#
# Over all data points:
# D       = 0.13231967302
# exponent= 0.995058841607
#
# r²     ~= 0.13231967302 d ^ 0.995058841607
# After last step:
# r_min   = 0.475012398231
# r_max   = 8.54131354146
# < r >   = 3.27423357034
# < r >²  = 10.7206054731
# < r² >  = 12.6532095515
# sigma_r = 1.39018131133
#
# Over all data points:
# D       = 0.117344126194
# exponent= 1.01249974042
#
# r²     ~= 0.117344126194 d ^ 1.01249974042
# After last step:
# r_min   = 0.343478393864
# r_max   = 7.75754812664
# < r >   = 3.31793746134
# < r >²  = 11.0087089974
# < r² >  = 12.7788140824
# sigma_r = 1.33045296235
#
# Over all data points:
# D       = 0.0910102525295
# exponent= 1.07245566962
#
# r²     ~= 0.0910102525295 d ^ 1.07245566962
# After last step:
# r_min   = 0.242139242193
# r_max   = 8.5975726993
# < r >   = 3.07706865244
# < r >²  = 9.4683514918
# < r² >  = 11.5921067973
# sigma_r = 1.45731098449
#
# Over all data points:
# D       = 0.138372439506
# exponent= 0.959355106531
#
# r²     ~= 0.138372439506 d ^ 0.959355106531
# After last step:
# r_min   = 0.74304481232
# r_max   = 8.53596367442
# < r >   = 3.24978820828
# < r >²  = 10.5611233987
# < r² >  = 12.1617516878
# sigma_r = 1.26515939278
#
# Over all data points:
# D       = 0.110172126363
# exponent= 1.02296096118
#
# r²     ~= 0.110172126363 d ^ 1.02296096118
# After last step:
# r_min   = 0.507248186782
# r_max   = 7.98133071563
# < r >   = 3.16085779136
# < r >²  = 9.99102197722
# < r² >  = 11.7305954855
# sigma_r = 1.31892892464
#
# Over all data points:
# D       = 0.0793686239412
# exponent= 1.08589245662
#
# r²     ~= 0.0793686239412 d ^ 1.08589245662
# After last step:
# r_min   = 0.359848460166
# r_max   = 7.76200529561
# < r >   = 3.0721772433
# < r >²  = 9.43827301422
# < r² >  = 11.2537689216
# sigma_r = 1.34740339447
#
# Over all data points:
# D       = 0.103390869325
# exponent= 1.01912715331
#
# r²     ~= 0.103390869325 d ^ 1.01912715331
# After last step:
# r_min   = 0.115394813247
# r_max   = 7.23754401951
# < r >   = 3.101860666
# < r >²  = 9.6215395913
# < r² >  = 11.2238341716
# sigma_r = 1.26581775163
#
# Over all data points:
# D       = 0.131278654081
# exponent= 0.972243499771
#
# r²     ~= 0.131278654081 d ^ 0.972243499771
# After last step:
# r_min   = 0.290799650259
# r_max   = 7.81003885896
# < r >   = 2.99341534714
# < r >²  = 8.96053544047
# < r² >  = 10.5540247057
# sigma_r = 1.26233484673
#
# Over all data points:
# D       = 0.0905628104983
# exponent= 1.03883140434
#
# r²     ~= 0.0905628104983 d ^ 1.03883140434
# After last step:
# r_min   = 0.164004557551
# r_max   = 8.11179748603
# < r >   = 2.96273753518
# < r >²  = 8.77781370238
# < r² >  = 10.6094658889
# sigma_r = 1.3533854538
#
# Over all data points:
# D       = 0.0664052405609
# exponent= 1.08806616396
#
# r²     ~= 0.0664052405609 d ^ 1.08806616396
# After last step:
# r_min   = 0.433678703506
# r_max   = 6.51361568807
# < r >   = 3.06640091495
# < r >²  = 9.40281457119
# < r² >  = 10.9710584638
# sigma_r = 1.2522954494
#
# Over all data points:
# D       = 0.106742566273
# exponent= 1.00194361357
#
# r²     ~= 0.106742566273 d ^ 1.00194361357
# After last step:
# r_min   = 0.42430175233
# r_max   = 6.70706171605
# < r >   = 3.0938274698
# < r >²  = 9.57176841289
# < r² >  = 11.5676575764
# sigma_r = 1.41275941461
#
# Over all data points:
# D       = 0.122514780951
# exponent= 0.984980598092
#
# r²     ~= 0.122514780951 d ^ 0.984980598092
# After last step:
# r_min   = 0.369243281419
# r_max   = 7.24465683761
# < r >   = 3.08685150507
# < r >²  = 9.52865221437
# < r² >  = 11.3278936859
# sigma_r = 1.34135806986
#
# Over all data points:
# D       = 0.0956569189453
# exponent= 1.04656909887
#
# r²     ~= 0.0956569189453 d ^ 1.04656909887
# After last step:
# r_min   = 0.357044013757
# r_max   = 6.81876582516
# < r >   = 2.93496266577
# < r >²  = 8.61400584944
# < r² >  = 10.1910882484
# sigma_r = 1.25581941337
#
# Over all data points:
# D       = 0.083426057661
# exponent= 1.04397971841
#
# r²     ~= 0.083426057661 d ^ 1.04397971841

# %% [markdown]
# An overview of all results shows the dependency on the B field strength.

# %%
figure(figsize=(9, 5))
title('D ~ Brms, E=' + str(EMin / EeV) + ' EeV')
scatter(Bs, Ds, s=50)
grid()
ylabel('D')
xlabel('Brms [nG]')
legend()
show()

figure(figsize=(9, 5))
title('exponent ~ Brms, E=' + str(EMin / EeV) + ' EeV')
scatter(Bs, exponents, s=50)
grid()
ylabel('exponent')
xlabel('Brms [nG]')
legend()
show()

# %% [markdown]
# This looks like a rough dependency of D ~ 1 / B. The exponent stays close to 1 which is the diffusion realm. If it was going up to 2 we were back in the ballistic motion, but here diffusion is a good description of the motion.
